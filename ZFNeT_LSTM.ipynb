# %%
#IMPORT LIBRARIES
import pickle
import numpy as np
import os
from keras.callbacks import LearningRateScheduler,EarlyStopping
from keras.layers import Dense,Flatten,MaxPooling2D,Conv2D,BatchNormalization,LSTM,Permute,Reshape
from keras.regularizers import l2
from scipy.interpolate import splev, splrep
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.models import Sequential
from sklearn.model_selection import StratifiedKFold

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_dir="/content/drive/MyDrive/dataset/osa_data"

# %%
# DEEP LEARNING MODELS NEED TO VECTORS OR MATRIX WITH SAME SIZE
# R-R INTERVALS DONT HAVE SAME SIZE, SO WE NEED TO INTERPOLATE VECTORS TO GET VECTORS WITH SAME SIZE.
# BASED ON OUR EXPERIENCE INTERPOLATION IN 3 HZ BETTER AND ACCURATE.
ir = 3 # INTERPOLATION RATE(3HZ)
time_range= 60 # 60-s INTERVALS OF ECG SIGNALS
weight=1e-3 #  WEIGHT L2 FOR REGULARIZATION(AVODING OVERFITTING PARAMETER)
#------------------------------------------------------------------------------
# NORMALIZATION:
# DEEP LEARNING AND EVEN NEURAL NETWORKS INPUT SHOULD BE NORMALIZED:
# MIN-MAX METHOD APPLIED FOR SCALING:(Array-min(Array))/(max(Array)-min(Array))
scaler = lambda arr: (arr - np.min(arr)) / (np.max(arr) - np.min(arr))

# %%
# FIRSTLY WE PRE-PROCESSED OUR DATA IN "apnea-detection_TD3_Kfold.pkl" FILE
# IN PRE-PROCESSING SECTION WE EXTRACT R-R INTERVALS AND R-PEAK AMPLITUDES
# IN THIS PART WE LOAD THIS DATA AND INTERPOLATE AND CONCATE FOR FEEDING TO NETWORKS
def load_data():
    tm = np.arange(0, (time_range), step=(1) / float(ir)) # TIME METRIC FOR INTERPOLATION
    # LOAD AND INTERPOLATE R-R INTERVALS AND R-PEAK AMPLITUDES
    with open(os.path.join(base_dir, "apnea-ecg.pkl"), 'rb') as f:
        apnea_ecg = pickle.load(f)

    x = []
    X, Y = apnea_ecg["o_train"], apnea_ecg["y_train"]
    for i in range(len(X)):
        (rri_tm, rri_signal), (amp_tm, amp_signal) = X[i]
        rri_interp_signal = splev(tm, splrep(rri_tm, scaler(rri_signal), k=3), ext=1)
        amp_interp_signal = splev(tm, splrep(amp_tm, scaler(amp_signal), k=3), ext=1)
        x.append([rri_interp_signal, amp_interp_signal])
    x = np.array(x, dtype="float32")


    x = np.expand_dims(x,1)
    x_final=np.array(x, dtype="float32").transpose((0,3,1,2))


    return x_final, Y

# %%
# CREAT DEEP LEARNING MODEL
def create_model(weight=1e-3):

    model= Sequential()
    model.add(Reshape((90,2,2),input_shape=(180,1,2)))
    model.add(Conv2D(96, kernel_size=(7,1), strides=(1,1), padding="same", activation="relu", kernel_initializer="he_normal",
                kernel_regularizer=l2(weight), bias_regularizer=l2(weight),input_shape=(180,1,2)))
    model.add(MaxPooling2D(pool_size=(3,1)))
    model.add(BatchNormalization())
    model.add(Conv2D(256, kernel_size=(5,1), strides=1, padding="same", activation="relu", kernel_initializer="he_normal",
                kernel_regularizer=l2(weight), bias_regularizer=l2(weight)))
    model.add(MaxPooling2D(pool_size=(3,1)))
    model.add(BatchNormalization())
    model.add(Conv2D(512, kernel_size=(3,1), strides=(1,1), padding="same", activation="relu", kernel_initializer="he_normal",
                kernel_regularizer=l2(weight), bias_regularizer=l2(weight)))
    model.add(Conv2D(1024, kernel_size=(3,1), strides=1, padding="same", activation="relu", kernel_initializer="he_normal",
                kernel_regularizer=l2(weight), bias_regularizer=l2(weight)))
    model.add(Conv2D(512, kernel_size=(3,1), strides=1, padding="same", activation="relu", kernel_initializer="he_normal",
                kernel_regularizer=l2(weight), bias_regularizer=l2(weight)))
    model.add(MaxPooling2D(pool_size=(3,1),strides=(2,1)))
    model.add(Permute((2,1,3)))
    model.add(Reshape((2,4*512)))

    model.add(LSTM(128, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(37, activation="relu"))

    model.add(Dense(2, activation="softmax"))
    return model

# %%
# Define learning rate schedule for preventing overfitting in deep learning methods:
def lr_schedule(epoch, lr):
    if epoch > 30 and \
            (epoch - 1) % 10 == 0:
        lr *= 0.1
    print("Learning rate: ", lr)
    return lr

# %%
# Compile and evaluate model:
if __name__ == "__main__":
    # loading Data:
    X, Y = load_data()
    # we have labels(Y) in a binary way 0 for normal and 1 for apnea patients
    # we want to classify data into 2-class so we changed y in a categorical way:
    Y = tf.keras.utils.to_categorical(Y, num_classes=2)
    # we used k-fold cross-validation for more reliable experiments:
    kfold = StratifiedKFold(n_splits=5, shuffle=True,random_state=7)
    cvscores = []
    ACC=[]
    SN=[]
    SP=[]
    F2=[]
    # separate train& test and then compile model
    for train, test in kfold.split(X, Y.argmax(1)):
     model = create_model()


     model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])
     # define callback for early stopping:
     lr_scheduler = LearningRateScheduler(lr_schedule)
     callback1 = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

     #10% of Data used for validation:
     X1,x_val,Y1,y_val=train_test_split(X[train],Y[train],test_size=0.10)

     history = model.fit(X1, Y1, batch_size=128, epochs=100, validation_data=(x_val, y_val),
                        callbacks=[callback1,lr_scheduler])

     model.save(os.path.join("model.ZFNet-LSTM.h5"))
# Out:
# Learning rate:  0.0010000000474974513
# Epoch 1/100
# 94/94 [==============================] - 20s 48ms/step - loss: 3.3181 - accuracy: 0.6960 - val_loss: 1.7316 - val_accuracy: 0.7517 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 2/100
# 94/94 [==============================] - 2s 25ms/step - loss: 1.2318 - accuracy: 0.7521 - val_loss: 0.9527 - val_accuracy: 0.7846 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 3/100
# 94/94 [==============================] - 2s 24ms/step - loss: 0.7909 - accuracy: 0.7956 - val_loss: 0.7185 - val_accuracy: 0.7891 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 4/100
# 94/94 [==============================] - 2s 24ms/step - loss: 0.6276 - accuracy: 0.8293 - val_loss: 0.6130 - val_accuracy: 0.8040 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 5/100
# 94/94 [==============================] - 2s 24ms/step - loss: 0.5575 - accuracy: 0.8389 - val_loss: 0.5863 - val_accuracy: 0.7973 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 6/100
# 94/94 [==============================] - 3s 33ms/step - loss: 0.5043 - accuracy: 0.8526 - val_loss: 0.5283 - val_accuracy: 0.8377 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 7/100
# 94/94 [==============================] - 4s 38ms/step - loss: 0.4803 - accuracy: 0.8559 - val_loss: 0.4646 - val_accuracy: 0.8534 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 8/100
# 94/94 [==============================] - 3s 32ms/step - loss: 0.4552 - accuracy: 0.8609 - val_loss: 0.5383 - val_accuracy: 0.7921 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 9/100
# 94/94 [==============================] - 3s 30ms/step - loss: 0.4413 - accuracy: 0.8674 - val_loss: 0.4608 - val_accuracy: 0.8534 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 10/100
# 94/94 [==============================] - 3s 30ms/step - loss: 0.4345 - accuracy: 0.8697 - val_loss: 0.4760 - val_accuracy: 0.8444 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 11/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4271 - accuracy: 0.8732 - val_loss: 0.4687 - val_accuracy: 0.8444 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 12/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4138 - accuracy: 0.8753 - val_loss: 0.4479 - val_accuracy: 0.8519 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 13/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.4025 - accuracy: 0.8785 - val_loss: 0.4478 - val_accuracy: 0.8549 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 14/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3949 - accuracy: 0.8872 - val_loss: 0.5936 - val_accuracy: 0.7861 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 15/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3838 - accuracy: 0.8898 - val_loss: 0.4211 - val_accuracy: 0.8714 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 16/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3743 - accuracy: 0.8947 - val_loss: 0.4752 - val_accuracy: 0.8444 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 17/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3729 - accuracy: 0.8982 - val_loss: 0.4347 - val_accuracy: 0.8631 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 18/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3705 - accuracy: 0.8993 - val_loss: 0.5014 - val_accuracy: 0.8250 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 19/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3662 - accuracy: 0.9025 - val_loss: 0.4448 - val_accuracy: 0.8773 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 20/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3448 - accuracy: 0.9131 - val_loss: 0.4630 - val_accuracy: 0.8579 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 21/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3514 - accuracy: 0.9112 - val_loss: 0.4513 - val_accuracy: 0.8639 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 22/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3457 - accuracy: 0.9135 - val_loss: 0.4854 - val_accuracy: 0.8594 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 23/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3395 - accuracy: 0.9151 - val_loss: 0.5161 - val_accuracy: 0.8444 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 24/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.3359 - accuracy: 0.9196 - val_loss: 0.5112 - val_accuracy: 0.8549 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 25/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3317 - accuracy: 0.9229 - val_loss: 0.5079 - val_accuracy: 0.8504 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 1/100
# 94/94 [==============================] - 8s 35ms/step - loss: 3.3439 - accuracy: 0.6204 - val_loss: 1.7349 - val_accuracy: 0.6126 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 2/100
# 94/94 [==============================] - 2s 26ms/step - loss: 1.1323 - accuracy: 0.7640 - val_loss: 0.9024 - val_accuracy: 0.7008 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 3/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.6839 - accuracy: 0.8298 - val_loss: 0.7951 - val_accuracy: 0.6948 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 4/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.5597 - accuracy: 0.8428 - val_loss: 0.7240 - val_accuracy: 0.7061 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 5/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4999 - accuracy: 0.8519 - val_loss: 0.5643 - val_accuracy: 0.8108 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 6/100
# 94/94 [==============================] - 3s 29ms/step - loss: 0.4711 - accuracy: 0.8569 - val_loss: 0.5436 - val_accuracy: 0.8123 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 7/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4440 - accuracy: 0.8674 - val_loss: 0.5020 - val_accuracy: 0.8295 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 8/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4283 - accuracy: 0.8698 - val_loss: 0.4872 - val_accuracy: 0.8504 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 9/100
# 94/94 [==============================] - 3s 32ms/step - loss: 0.4132 - accuracy: 0.8785 - val_loss: 0.5076 - val_accuracy: 0.8332 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 10/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4053 - accuracy: 0.8821 - val_loss: 0.5213 - val_accuracy: 0.8302 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 11/100
# 94/94 [==============================] - 3s 29ms/step - loss: 0.4005 - accuracy: 0.8811 - val_loss: 0.6436 - val_accuracy: 0.7442 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 12/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3858 - accuracy: 0.8902 - val_loss: 0.4773 - val_accuracy: 0.8497 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 13/100
# 94/94 [==============================] - 2s 27ms/step - loss: 0.3897 - accuracy: 0.8869 - val_loss: 0.4963 - val_accuracy: 0.8519 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 14/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3683 - accuracy: 0.9020 - val_loss: 0.5166 - val_accuracy: 0.8384 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 15/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3652 - accuracy: 0.9030 - val_loss: 0.5367 - val_accuracy: 0.8190 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 16/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3619 - accuracy: 0.9037 - val_loss: 0.5490 - val_accuracy: 0.8250 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 17/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3590 - accuracy: 0.9062 - val_loss: 0.5071 - val_accuracy: 0.8377 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 18/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3442 - accuracy: 0.9169 - val_loss: 0.5081 - val_accuracy: 0.8482 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 19/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3436 - accuracy: 0.9185 - val_loss: 0.5182 - val_accuracy: 0.8549 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 20/100
# 94/94 [==============================] - 2s 27ms/step - loss: 0.3337 - accuracy: 0.9249 - val_loss: 0.7473 - val_accuracy: 0.7457 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 21/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3258 - accuracy: 0.9284 - val_loss: 0.5644 - val_accuracy: 0.8527 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 22/100
# 94/94 [==============================] - 3s 33ms/step - loss: 0.3360 - accuracy: 0.9260 - val_loss: 0.5428 - val_accuracy: 0.8377 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 1/100
# 94/94 [==============================] - 9s 33ms/step - loss: 3.1500 - accuracy: 0.7185 - val_loss: 1.5827 - val_accuracy: 0.7420 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 2/100
# 94/94 [==============================] - 2s 26ms/step - loss: 1.0817 - accuracy: 0.8018 - val_loss: 0.9328 - val_accuracy: 0.7135 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 3/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.6909 - accuracy: 0.8363 - val_loss: 0.7250 - val_accuracy: 0.7562 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 4/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.5811 - accuracy: 0.8479 - val_loss: 0.6007 - val_accuracy: 0.8212 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 5/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.5238 - accuracy: 0.8584 - val_loss: 0.5544 - val_accuracy: 0.8220 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 6/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4995 - accuracy: 0.8537 - val_loss: 0.5831 - val_accuracy: 0.8003 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 7/100
# 94/94 [==============================] - 2s 27ms/step - loss: 0.4659 - accuracy: 0.8649 - val_loss: 0.6127 - val_accuracy: 0.7966 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 8/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4517 - accuracy: 0.8677 - val_loss: 0.5350 - val_accuracy: 0.8145 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 9/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.4382 - accuracy: 0.8726 - val_loss: 0.5204 - val_accuracy: 0.8302 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 10/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.4273 - accuracy: 0.8759 - val_loss: 0.4847 - val_accuracy: 0.8392 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 11/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4238 - accuracy: 0.8771 - val_loss: 0.5604 - val_accuracy: 0.8085 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 12/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4036 - accuracy: 0.8850 - val_loss: 0.5076 - val_accuracy: 0.8287 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 13/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3917 - accuracy: 0.8909 - val_loss: 0.4779 - val_accuracy: 0.8579 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 14/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3875 - accuracy: 0.8924 - val_loss: 0.4931 - val_accuracy: 0.8422 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 15/100
# 94/94 [==============================] - 3s 29ms/step - loss: 0.3766 - accuracy: 0.9017 - val_loss: 0.5817 - val_accuracy: 0.7936 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 16/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3689 - accuracy: 0.9057 - val_loss: 0.5112 - val_accuracy: 0.8399 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 17/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3700 - accuracy: 0.9071 - val_loss: 0.5802 - val_accuracy: 0.8078 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 18/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3751 - accuracy: 0.9132 - val_loss: 0.5504 - val_accuracy: 0.8489 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 19/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3757 - accuracy: 0.9165 - val_loss: 0.7169 - val_accuracy: 0.8115 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 20/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3658 - accuracy: 0.9250 - val_loss: 0.6126 - val_accuracy: 0.8205 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 21/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3558 - accuracy: 0.9310 - val_loss: 0.6704 - val_accuracy: 0.8070 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 22/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3386 - accuracy: 0.9372 - val_loss: 0.6585 - val_accuracy: 0.8227 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 23/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3308 - accuracy: 0.9449 - val_loss: 0.6801 - val_accuracy: 0.8422 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 1/100
# 94/94 [==============================] - 9s 35ms/step - loss: 3.1237 - accuracy: 0.6444 - val_loss: 1.5116 - val_accuracy: 0.7195 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 2/100
# 94/94 [==============================] - 2s 27ms/step - loss: 1.0337 - accuracy: 0.7643 - val_loss: 0.8681 - val_accuracy: 0.7248 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 3/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.6660 - accuracy: 0.8173 - val_loss: 0.6438 - val_accuracy: 0.8018 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 4/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.5559 - accuracy: 0.8412 - val_loss: 0.6164 - val_accuracy: 0.7794 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 5/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.5114 - accuracy: 0.8466 - val_loss: 0.5643 - val_accuracy: 0.8078 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 6/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.4678 - accuracy: 0.8569 - val_loss: 0.4971 - val_accuracy: 0.8392 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 7/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4556 - accuracy: 0.8601 - val_loss: 0.5307 - val_accuracy: 0.8025 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 8/100
# 94/94 [==============================] - 2s 25ms/step - loss: 0.4353 - accuracy: 0.8669 - val_loss: 0.5164 - val_accuracy: 0.8205 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 9/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4317 - accuracy: 0.8655 - val_loss: 0.4863 - val_accuracy: 0.8287 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 10/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4136 - accuracy: 0.8736 - val_loss: 0.4887 - val_accuracy: 0.8272 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 11/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.4040 - accuracy: 0.8757 - val_loss: 0.5238 - val_accuracy: 0.8160 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 12/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3966 - accuracy: 0.8781 - val_loss: 0.5054 - val_accuracy: 0.8235 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 13/100
# 94/94 [==============================] - 2s 27ms/step - loss: 0.3887 - accuracy: 0.8834 - val_loss: 0.4836 - val_accuracy: 0.8325 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 14/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3839 - accuracy: 0.8879 - val_loss: 0.4777 - val_accuracy: 0.8399 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 15/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3708 - accuracy: 0.8955 - val_loss: 0.5248 - val_accuracy: 0.8250 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 16/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3782 - accuracy: 0.8933 - val_loss: 0.5284 - val_accuracy: 0.8414 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 17/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3574 - accuracy: 0.8994 - val_loss: 0.4805 - val_accuracy: 0.8399 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 18/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3520 - accuracy: 0.9033 - val_loss: 0.6785 - val_accuracy: 0.7577 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 19/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3415 - accuracy: 0.9111 - val_loss: 0.6176 - val_accuracy: 0.8055 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 20/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3506 - accuracy: 0.9078 - val_loss: 0.5496 - val_accuracy: 0.8265 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 21/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3366 - accuracy: 0.9144 - val_loss: 0.5604 - val_accuracy: 0.8250 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 22/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3316 - accuracy: 0.9179 - val_loss: 0.5691 - val_accuracy: 0.8332 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 23/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3208 - accuracy: 0.9211 - val_loss: 0.5416 - val_accuracy: 0.8369 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 24/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3152 - accuracy: 0.9249 - val_loss: 0.5627 - val_accuracy: 0.8085 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 1/100
# 94/94 [==============================] - 9s 50ms/step - loss: 2.6994 - accuracy: 0.6965 - val_loss: 1.3363 - val_accuracy: 0.6245 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 2/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.8612 - accuracy: 0.7962 - val_loss: 0.8799 - val_accuracy: 0.6462 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 3/100
# 94/94 [==============================] - 2s 27ms/step - loss: 0.6313 - accuracy: 0.8294 - val_loss: 0.5969 - val_accuracy: 0.8295 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 4/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.5551 - accuracy: 0.8417 - val_loss: 0.5877 - val_accuracy: 0.8115 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 5/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.5071 - accuracy: 0.8528 - val_loss: 0.5260 - val_accuracy: 0.8362 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 6/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.4724 - accuracy: 0.8603 - val_loss: 0.5368 - val_accuracy: 0.8078 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 7/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.4615 - accuracy: 0.8639 - val_loss: 0.5333 - val_accuracy: 0.8085 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 8/100
# 94/94 [==============================] - 2s 27ms/step - loss: 0.4434 - accuracy: 0.8664 - val_loss: 0.4876 - val_accuracy: 0.8414 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 9/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.4299 - accuracy: 0.8715 - val_loss: 0.4804 - val_accuracy: 0.8325 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 10/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4157 - accuracy: 0.8762 - val_loss: 0.4682 - val_accuracy: 0.8527 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 11/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.4078 - accuracy: 0.8786 - val_loss: 0.4725 - val_accuracy: 0.8362 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 12/100
# 94/94 [==============================] - 3s 29ms/step - loss: 0.3965 - accuracy: 0.8877 - val_loss: 0.4736 - val_accuracy: 0.8564 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 13/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3961 - accuracy: 0.8871 - val_loss: 0.4387 - val_accuracy: 0.8579 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 14/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3813 - accuracy: 0.8918 - val_loss: 0.4770 - val_accuracy: 0.8414 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 15/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3792 - accuracy: 0.8922 - val_loss: 0.5494 - val_accuracy: 0.8257 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 16/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3652 - accuracy: 0.8998 - val_loss: 0.4846 - val_accuracy: 0.8377 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 17/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3594 - accuracy: 0.9023 - val_loss: 0.6461 - val_accuracy: 0.7996 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 18/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3589 - accuracy: 0.9059 - val_loss: 0.5105 - val_accuracy: 0.8332 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 19/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3376 - accuracy: 0.9145 - val_loss: 0.5361 - val_accuracy: 0.8242 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 20/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3360 - accuracy: 0.9189 - val_loss: 0.5106 - val_accuracy: 0.8422 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 21/100
# 94/94 [==============================] - 2s 26ms/step - loss: 0.3392 - accuracy: 0.9200 - val_loss: 0.5347 - val_accuracy: 0.8340 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 22/100
# 94/94 [==============================] - 3s 27ms/step - loss: 0.3267 - accuracy: 0.9259 - val_loss: 0.5239 - val_accuracy: 0.8527 - lr: 0.0010
# Learning rate:  0.0010000000474974513
# Epoch 23/100
# 94/94 [==============================] - 3s 28ms/step - loss: 0.3149 - accuracy: 0.9298 - val_loss: 0.5740 - val_accuracy: 0.8287 - lr: 0.0010

# %%
     loss, accuracy = model.evaluate(X[test], Y[test])

     y_score = model.predict(X[test])

     y_predict= np.argmax(y_score, axis=-1)
     y_training = np.argmax(Y[test], axis=-1)
     # Confusion matrix:
     from sklearn.metrics import confusion_matrix
     from sklearn.metrics import f1_score
     C = confusion_matrix(y_training, y_predict, labels=(1, 0))
     TP, TN, FP, FN = C[0, 0], C[1, 1], C[1, 0], C[0, 1]
     acc, sn, sp = 1. * (TP + TN) / (TP + TN + FP + FN), 1. * TP / (TP + FN), 1. * TN / (TN + FP)
     f2=f1_score(y_training, y_predict)

     ACC.append(acc * 100)
     SN.append(sn * 100)
     SP.append(sp * 100)
     F2.append(f2 * 100)
# Out:
# 105/105 [==============================] - 1s 6ms/step - loss: 0.4225 - accuracy: 0.8695
# 105/105 [==============================] - 1s 3ms/step

# %%
    loss, accuracy = model.evaluate(x_val, y_val) # test the model
    print("Test loss: ", loss)
    print("Accuracy: ", accuracy)

    # save prediction score
    y_score = model.predict(x_val)
    #output = pd.DataFrame({"y_true": y_test[:, 1], "y_score": y_score[:, 1], "subject": groups_test})
    #output.to_csv(os.path.join("base_dir", "LeNet.csv"), index=False)
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# 42/42 [==============================] - 0s 7ms/step - loss: 0.4387 - accuracy: 0.8579
# Test loss:  0.43871355056762695
# Accuracy:  0.857890784740448
# 42/42 [==============================] - 0s 3ms/step
